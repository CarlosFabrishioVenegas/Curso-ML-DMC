# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosFabrishioVenegas/Curso-ML-DMC/blob/main/0_Programation/DMC_02_introducci%C3%B3n_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Herramientaas!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#BIBLIOGRAFÍAS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#https://learning.oreilly.com/home/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Estos son los elementos que ayudan a la programación, lo que tenemos que entender
#Interprete: Es el motor central que va a ejecutr python
#Ide: es un entorno que nos ayuda a interacturar con el interprete
#Terminal: ayuda a hablar con el interprete
#Gestor de paquete: Es el que se usr para instalar y manejar bibliotecas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Local: que uses tu ram
#Nube: computadora virtual, esto comienza a suceder por la cantidad de datos que existe
#      fue una solución para el tratamiento y trabajo de data, nace apache spark
#      continuó desarrolando

# %%
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#VM de GCE, construir modelos a escalas más grandes, tener una estructura
#

# %%
a=15//4

# %%
type(a)
# Out:
# int

# %%
#Este es un cambio
